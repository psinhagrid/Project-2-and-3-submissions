# %% [markdown]
# # Evaluating The Results :

# %% [markdown]
# ### Import Necessary Library

# %%
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration
import numpy as np
import datasets
import os
import sys
import importlib

import io
import joblib
import ast
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt

from datasets import load_dataset
import datasets
import pandas as pd
import re

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from langdetect import detect

from sklearn import model_selection, naive_bayes, svm
from sklearn.model_selection import validation_curve
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import GridSearchCV
import pandas as pd
from sklearn import svm, metrics
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier


os.environ["TOKENIZERS_PARALLELISM"] = "false"

import warnings

# Disable the specific UserWarning
warnings.filterwarnings("ignore", message="Using the model-agnostic default `max_length`")

# Performing TFIDF vectorisation
tfidf_vectorizer = TfidfVectorizer()

# %% [markdown]
# ### Importing our model building file.

# %%
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
src_data_directory = os.path.join(parent_directory, "src", "model")

sys.path.append(src_data_directory)

# %%
import model_train
importlib.reload(model_train)
# Out:
# Enter 1 if only question given              :
# Enter 2 if only image given                 :
# Enter 3 if both question and image given    :
# Data Frame Obtained
# <module 'model_train' from '/Users/psinha/Desktop/Structred Folder/src/model/model_train.py'>

# %% [markdown]
# ### We can call our evaluation function to evaluate our model

# %%
# Our function will plot confusion matrix for all classes as shown below
model_train.evaluation_of_model("SVM", "confusion_metric")
# Out:
# Classification Report For answer_type
#                precision    recall  f1-score   support
#
#        float       0.65      0.34      0.45        87
#         text       0.88      0.90      0.89       796
#         list       1.00      0.40      0.57         5
#      integer       0.93      0.96      0.94      1169
#
#     accuracy                           0.91      2057
#    macro avg       0.87      0.65      0.71      2057
# weighted avg       0.90      0.91      0.90      2057
# Classification Report For metadata_category
#                     precision    recall  f1-score   support
#
#       general-vqa       0.99      0.98      0.98       882
# math-targeted-vqa       0.98      0.99      0.99      1175
#
#          accuracy                           0.99      2057
#         macro avg       0.99      0.99      0.99      2057
#      weighted avg       0.99      0.99      0.99      2057
# Classification Report For metadata_task
# ...

# %%
# We can also find the accuracy of the SVM/ Naive Bayes for all class as demonstrated below using the same function.
model_train.evaluation_of_model("SVM", "accuracy")
# Out:
#  Accuracy of -> answer_type 90.71463296062227
#
#  Accuracy of -> metadata_category 98.59017987360234
#
#  Accuracy of -> metadata_task 97.52066115702479
#
#  Accuracy of -> metadata_context 95.23578026251823
#
#  Accuracy of -> metadata_grade 95.57608167233835
#
#  Accuracy of -> metadata_language 98.68740884783665
